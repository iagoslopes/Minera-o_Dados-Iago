# %% [markdown]
# <a href="https://colab.research.google.com/github/iagoslopes/Mineracao_Dados-Iago/blob/master/Iago_WebScraping_FATEC_PARTE_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# bibliotecas
# !pip install requests
# !pip install beautifulsoup4

# %%
import requests
from bs4 import BeautifulSoup

# URL do site de exemplo hospedado no GitHub Pages
url = 'https://books.toscrape.com/catalogue/category/books/fiction_10/index.html'

# %%
headers = {"User-agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/130.0.0.0 Safari/537.36"}

# %%
# Fazendo a requisição HTTP para obter o conteúdo da página
response = requests.get(url,headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
response.text
# Out:
# '\n\n<!DOCTYPE html>\n<!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->\n<!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->\n<!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->\n<!--[if gt IE 8]><!--> <html lang="en-us" class="no-js"> <!--<![endif]-->\n    <head>\n        <title>\n    Fiction | \n     Books to Scrape - Sandbox\n\n</title>\n\n        <meta http-equiv="content-type" content="text/html; charset=UTF-8" />\n        <meta name="created" content="24th Jun 2016 09:29" />\n        <meta name="description" content="\n    \n" />\n        <meta name="viewport" content="width=device-width" />\n        <meta name="robots" content="NOARCHIVE,NOCACHE" />\n\n        <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->\n        <!--[if lt IE 9]>\n        <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>\n        <![endif]-->\n\n        \n            <link rel="s
# ...

# %%
bonito = BeautifulSoup(response.text, 'html.parser')

# %%
print(bonito.prettify())
# Out:
# <!DOCTYPE html>
# <!--[if lt IE 7]>      <html lang="en-us" class="no-js lt-ie9 lt-ie8 lt-ie7"> <![endif]-->
# <!--[if IE 7]>         <html lang="en-us" class="no-js lt-ie9 lt-ie8"> <![endif]-->
# <!--[if IE 8]>         <html lang="en-us" class="no-js lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" lang="en-us">
#  <!--<![endif]-->
#  <head>
#   <title>
#    Fiction |
#      Books to Scrape - Sandbox
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="24th Jun 2016 09:29" name="created"/>
#   <meta content="
#
# " name="description"/>
#   <meta content="width=device-width" name="viewport"/>
#   <meta content="NOARCHIVE,NOCACHE" name="robots"/>
#   <!-- Le HTML5 shim, for IE6-8 support of HTML elements -->
#   <!--[if lt IE 9]>
#         <script src="//html5shim.googlecode.com/svn/trunk/html5.js"></script>
#         <![endif]-->
#   <link href="../../../../static/oscar/favicon.ico" rel="shortcut icon"/>
# ...

# %%
# Encontrando todos os produtos na página

produtos = bonito.find_all('article', class_='product_pod')
# produtos = bonito.find_all('h2')
produtos[0]
# Out:
# <article class="product_pod">
# <div class="image_container">
# <a href="../../../soumission_998/index.html"><img alt="Soumission" class="thumbnail" src="../../../../media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg"/></a>
# </div>
# <p class="star-rating One">
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# <i class="icon-star"></i>
# </p>
# <h3><a href="../../../soumission_998/index.html" title="Soumission">Soumission</a></h3>
# <div class="product_price">
# <p class="price_color">Â£50.10</p>
# <p class="instock availability">
# <i class="icon-ok"></i>
#
#         In stock
#
# </p>
# <form>
# <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
# </form>
# </div>
# </article>

# %%
nome_produto = produtos[0].find('h3').text
print("Produto Nome = ",nome_produto)
# Out:
# Produto Nome =  Soumission

# %%
preco_produto = produtos[0].find_all('p', class_='price_color')[0].text
preco_produto
# Out:
# 'Â£50.10'

# %%
instock_produto = produtos[0].find_all('p', class_='availability')[0].text
instock_produto
# Out:
# '\n\n    \n        In stock\n    \n'

# %%
produtos = bonito.find_all('article', class_='product_pod')

# %%
produtos
# Out:
# [<article class="product_pod">
#  <div class="image_container">
#  <a href="../../../soumission_998/index.html"><img alt="Soumission" class="thumbnail" src="../../../../media/cache/3e/ef/3eef99c9d9adef34639f510662022830.jpg"/></a>
#  </div>
#  <p class="star-rating One">
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  <i class="icon-star"></i>
#  </p>
#  <h3><a href="../../../soumission_998/index.html" title="Soumission">Soumission</a></h3>
#  <div class="product_price">
#  <p class="price_color">Â£50.10</p>
#  <p class="instock availability">
#  <i class="icon-ok"></i>
#
#          In stock
#
#  </p>
#  <form>
#  <button class="btn btn-primary btn-block" data-loading-text="Adding..." type="submit">Add to basket</button>
#  </form>
#  </div>
#  </article>,
#  <article class="product_pod">
#  <div class="image_container">
# ...

# %%
import pandas as pd

# Verificando se a requisição foi bem-sucedida
if response.status_code == 200:
    print("Conexão bem-sucedida!")
    soup = BeautifulSoup(response.text, 'html.parser')
    produtos = soup.find_all('article', class_='product_pod')

    livros = []

    for produto in produtos:
        nome = produto.find('h3').text
        preco_str = produto.find('p', class_='price_color').text.replace('Â', '').replace('£', '')
        preco = float(preco_str)
        estoque = produto.find_all('p')[2].text.strip()

        # Adicionando o livro à lista como um dicionário
        livros.append({'nome': nome, 'preco': preco, 'estoque': estoque})

        print("Nome:", nome)
        print("Preço:", preco)
        print("Estoque:", estoque)
        print("-" * 20)

    # Criando um DataFrame com os dados dos livros
    df = pd.DataFrame(livros)

    # Calculando o preço médio
    preco_medio = df['preco'].mean()
    print(f"\nPreço médio dos livros: £{preco_medio:.2f}")

    # Contando os livros em estoque
    livros_em_estoque = df['estoque'].str.contains("In stock").sum()
    print(f"Total de livros em estoque: {livros_em_estoque}")

    # Encontrando os 3 livros mais caros
    livros_mais_caros = df.nlargest(3, 'preco')
    print("\nOs 3 livros mais caros são:")
    print(livros_mais_caros[['nome', 'preco']])
else:
    print("Erro ao acessar o site.")
# Out:
# Conexão bem-sucedida!
# Nome: Soumission
# Preço: 50.1
# Estoque: In stock
# --------------------
# Nome: Private Paris (Private #10)
# Preço: 47.61
# Estoque: In stock
# --------------------
# Nome: We Love You, Charlie ...
# Preço: 50.27
# Estoque: In stock
# --------------------
# Nome: Thirst
# Preço: 17.27
# Estoque: In stock
# --------------------
# Nome: The Murder That Never ...
# Preço: 54.11
# Estoque: In stock
# --------------------
# Nome: Tuesday Nights in 1980
# Preço: 21.04
# Estoque: In stock
# --------------------
# Nome: The Vacationers
# Preço: 42.15
# Estoque: In stock
# --------------------
# Nome: The Regional Office Is ...
# Preço: 51.36
# Estoque: In stock
# --------------------
# Nome: Finders Keepers (Bill Hodges ...
# Preço: 53.53
# Estoque: In stock
# --------------------
# Nome: The Time Keeper
# Preço: 27.88
# Estoque: In stock
# --------------------
# Nome: The Testament of Mary
# Preço: 52.67
# Estoque: In stock
# --------------------
# ...
